# %% [markdown]
# # LAB 1: Probability Concepts, Indepdenece and Random Variables
#
# In this lab you will use python to study the following topics:
#
# - How to simulate random experiment outcomes using numpy arrays.
# - How to estimate the probability of an event using the relative frequency approach.
# - Simulate independent events.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for a dataset.
# - Calculate covariance and correlation coeffecient of two random variables.

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np

# matplotlib library
import matplotlib.pyplot as plt

import pandas as pd

# %% [markdown]
# # Problem 1
#
# Use numpy to simulate the vector outcomes for repeating the following random experiments $1000$ times and use the relative frequency to compute the probability of the corresponding events:
#
# 1. **Experiment:** Flipping a fair coin, **Event:** A head occurs.
#
# Observe how changing the number of repetition affects the computed probabilities.
#
# **Hints:**
# - Use [numpy.random.randint](https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html) or [numpy.random.choice](https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html) to simulate the experiment.
# - Other useful functions [numpy.arange](https://numpy.org/doc/stable/reference/generated/numpy.arange.html), [numpy.cumsum](https://numpy.org/doc/stable/reference/generated/numpy.cumsum.html), [numpy.sum](https://numpy.org/doc/stable/reference/generated/numpy.sum.html), and [matplotlib.pyplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
n = np.array([10,50,100,500,1000,5000,10000,50000,1000000])
for i in n:
    exp = np.random.randint(0,2,size = i)
    print("n ={} , p(e) = {}".format(i,exp.mean()))
    print("----------------------------------------")
 
experiment = np.random.randint(0,2,size = 1000) 
probability = np.cumsum(experiment)/np.arange(1,1000+1)
plt.axhline(y = 0.5,c = "r")
plt.plot(probability)
plt.grid()
# Out:
# n =10 , p(e) = 0.7
# ----------------------------------------
# n =50 , p(e) = 0.48
# ----------------------------------------
# n =100 , p(e) = 0.5
# ----------------------------------------
# n =500 , p(e) = 0.482
# ----------------------------------------
# n =1000 , p(e) = 0.481
# ----------------------------------------
# n =5000 , p(e) = 0.4996
# ----------------------------------------
# n =10000 , p(e) = 0.5043
# ----------------------------------------
# n =50000 , p(e) = 0.50226
# ----------------------------------------
# n =1000000 , p(e) = 0.50041
# ----------------------------------------

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.6
# -----------------------------------------
# n = 50, P(e) = 0.48
# -----------------------------------------
# n = 100, P(e) = 0.52
# -----------------------------------------
# n = 500, P(e) = 0.498
# -----------------------------------------
# n = 1000, P(e) = 0.475
# -----------------------------------------
# n = 5000, P(e) = 0.4998
# -----------------------------------------
# n = 10000, P(e) = 0.5022
# -----------------------------------------
# n = 50000, P(e) = 0.5011
# -----------------------------------------
# n = 100000, P(e) = 0.49788
# -----------------------------------------

# %% [markdown]
# 2. **Experiment:** Rolling a fair die, **Event:** Number 5 occurs.

# %%
n = np.array([10,50,100,500,1000,5000,10000,50000,1000000])
for i in n:
    exp = np.random.randint(1,7,size = i)
    print("n ={} , p(e) = {}".format(i,(exp==5).mean()))
    print("----------------------------------------")
 
experiment = np.random.randint(1,7,size = 1000) 
probability = np.cumsum(experiment==5)/np.arange(1,1000+1)
plt.axhline(y =1/6,c = "r")
plt.plot(probability)
plt.grid()
# Out:
# n =10 , p(e) = 0.2
# ----------------------------------------
# n =50 , p(e) = 0.16
# ----------------------------------------
# n =100 , p(e) = 0.08
# ----------------------------------------
# n =500 , p(e) = 0.204
# ----------------------------------------
# n =1000 , p(e) = 0.183
# ----------------------------------------
# n =5000 , p(e) = 0.162
# ----------------------------------------
# n =10000 , p(e) = 0.1688
# ----------------------------------------
# n =50000 , p(e) = 0.1676
# ----------------------------------------
# n =1000000 , p(e) = 0.166125
# ----------------------------------------

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.2
# -----------------------------------------
# n = 50, P(e) = 0.12
# -----------------------------------------
# n = 100, P(e) = 0.19
# -----------------------------------------
# n = 500, P(e) = 0.166
# -----------------------------------------
# n = 1000, P(e) = 0.151
# -----------------------------------------
# n = 5000, P(e) = 0.1648
# -----------------------------------------
# n = 10000, P(e) = 0.1663
# -----------------------------------------
# n = 50000, P(e) = 0.1661
# -----------------------------------------
# n = 100000, P(e) = 0.16817
# -----------------------------------------

# %% [markdown]
# 3. **Experiment:** Rolling a fair die, **Event:** A number greater than 3 occurs.

# %%
n = np.array([10,50,100,500,1000,5000,10000,50000,1000000])
for i in n:
    exp = np.random.randint(1,7,size = i)
    print("n ={} , p(e) = {}".format(i,(exp>3).mean()))
    print("----------------------------------------")
 
experiment = np.random.randint(1,7,size = 1000) 
probability = np.cumsum(experiment>3)/np.arange(1,1000+1)
plt.axhline(y =1/2,c = "r")
plt.plot(probability)
plt.grid()
# Out:
# n =10 , p(e) = 0.5
# ----------------------------------------
# n =50 , p(e) = 0.46
# ----------------------------------------
# n =100 , p(e) = 0.58
# ----------------------------------------
# n =500 , p(e) = 0.482
# ----------------------------------------
# n =1000 , p(e) = 0.486
# ----------------------------------------
# n =5000 , p(e) = 0.5052
# ----------------------------------------
# n =10000 , p(e) = 0.4888
# ----------------------------------------
# n =50000 , p(e) = 0.50182
# ----------------------------------------
# n =1000000 , p(e) = 0.499231
# ----------------------------------------

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.6
# -----------------------------------------
# n = 50, P(e) = 0.48
# -----------------------------------------
# n = 100, P(e) = 0.44
# -----------------------------------------
# n = 500, P(e) = 0.496
# -----------------------------------------
# n = 1000, P(e) = 0.489
# -----------------------------------------
# n = 5000, P(e) = 0.5052
# -----------------------------------------
# n = 10000, P(e) = 0.4962
# -----------------------------------------
# n = 50000, P(e) = 0.49842
# -----------------------------------------
# n = 100000, P(e) = 0.49983
# -----------------------------------------

# %% [markdown]
# 4. **Experiment:** Rolling two fair dice, **Event:** Sum of two dice equal 5.

# %%
n = np.array([10,50,100,500,1000,5000,10000,50000,1000000])
for i in n:
    exp = np.random.randint(1,7,size = (i,2))
    print("n ={} , p(e) = {}".format(i,(exp.sum(axis = 1)==5).mean()))
    print("----------------------------------------")
 
experiment = np.random.randint(1,7,size = (1000,2) )
probability = np.cumsum(experiment.sum(axis = 1)==5)/np.arange(1,1000+1)
plt.axhline(y =1/9,c = "r")
plt.plot(probability)
plt.grid()
# Out:
# n =10 , p(e) = 0.0
# ----------------------------------------
# n =50 , p(e) = 0.08
# ----------------------------------------
# n =100 , p(e) = 0.07
# ----------------------------------------
# n =500 , p(e) = 0.112
# ----------------------------------------
# n =1000 , p(e) = 0.099
# ----------------------------------------
# n =5000 , p(e) = 0.1074
# ----------------------------------------
# n =10000 , p(e) = 0.115
# ----------------------------------------
# n =50000 , p(e) = 0.11086
# ----------------------------------------
# n =1000000 , p(e) = 0.110991
# ----------------------------------------

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.1
# -----------------------------------------
# n = 50, P(e) = 0.04
# -----------------------------------------
# n = 100, P(e) = 0.11
# -----------------------------------------
# n = 500, P(e) = 0.116
# -----------------------------------------
# n = 1000, P(e) = 0.112
# -----------------------------------------
# n = 5000, P(e) = 0.1134
# -----------------------------------------
# n = 10000, P(e) = 0.1056
# -----------------------------------------
# n = 50000, P(e) = 0.10812
# -----------------------------------------
# n = 100000, P(e) = 0.10955
# -----------------------------------------

# %% [markdown]
# # Problem 2
#
# Simulate the experiment of tossing $1000$ times a coin with probability of **head (coded as $1$) equal to $0.4$** and probability of **tail (coded as $0$) equal to $0.6$**. How can you check if the simulation of the experiment of been running as expected.
#
# **Hint**: Use [matplotlib.pyplot.hist¶
# ](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)

# %%
exp = np.random.choice([1,0], size = 1000 , p = [0.4,0.6])
plt.hist(exp)
plt.grid()

# %%
#type your code here:

# %% [markdown]
# # Problem 3: Independence
#
# Use NumPy to create simulations and compute **empirical  probability** for the following outcomes. Compare the results with the **theoretical probability**.
#
# 1. Two fair coin flips produce exactly two heads

# %%
#type your code here:

# simulate 1 million tests of two fair coin flips
exp = np.random.randint(0,2,size = (1*(10**6),2) )

# sums of all tests
sum = exp.sum(axis = 1)

# proportion of tests that produced exactly two heads
print((sum==2).mean())
# Out:
# 0.2498

# %% [markdown]
# 2. Three fair coin flips produce exactly one head

# %%
#type your code here:

# simulate 1 million tests of three fair coin flips
exp = np.random.randint(0,2,size = (1*(10**6),3) )

# sums of all tests
sum = exp.sum(axis = 1)

# proportion of tests that produced exactly one head
print((sum==1).mean())
# Out:
# 0.375142

# %%
#type your code here:

# simulate 1 million tests of three fair coin flips


# sums of all tests


# proportion of tests that produced exactly one head
# Out:
# 0.374819

# %% [markdown]
# 3. Three biased coin flips with P(H) = 0.6 produce exactly one head

# %%
#type your code here:


# simulate 1 million tests of three biased coin flips
# hint: use np.random.choice()
exp = np.random.choice([1,0], size = (1*(10**6),3) , p = [0.6,0.4])

# sums of all tests
sum = exp.sum(axis = 1)

# proportion of tests that produced exactly one head
print((sum==1).mean())
# Out:
# 0.288181

# %%
#type your code here:


# simulate 1 million tests of three biased coin flips
# hint: use np.random.choice()


# sums of all tests


# proportion of tests that produced exactly one head
# Out:
# 0.288288

# %% [markdown]
# # Problem 4:Random Variables Statistical Tools
# Simulate Rolling a fair die $1000$ times. Then calculate the following:
#
# - Sample mean
# - Sample variance
# - Sample standard deviation
#
# Compare the results with the theoretical probability.

# %%
exp = np.random.randint(1,7,size = (1000))
print("Sample mean: {}".format(exp.mean()))
print("Sample variance: {}".format(np.var(exp)))
print("Sample standard deviation: {}".format(np.std(exp)))
# Out:
# Sample mean: 3.488
# Sample variance: 2.8758559999999997
# Sample standard deviation: 1.6958348976241762

# %%
#type your code here:
# Out:
# Sample mean: 3.463
# Sample variance: 3.005636636636637
# Sample standard deviation: 1.7336772008181445
# 3.463
# 3.005636636636637
# 1.7336772008181445

# %% [markdown]
# # Problem 5: Correlation and Covariance
#
# The CSV file includes a hourly/daily summary for Szeged, Hungary area, between 2006 and 2016. After inspecting the data:
#
# - Calculate the covariance and correlation coeffecient between temperature and apparent temperature
# - Calculate the covariance and correlation coeffecient between temperature and humidity

# %%
df = pd.read_csv('weatherHistory.csv')
temperature = df['Temperature (C)'].to_numpy().reshape(-1, 1)
apparant_temp = df['Apparent Temperature (C)'].to_numpy().reshape(-1, 1)
humidity = df['Humidity'].to_numpy().reshape(-1, 1)

# %%
plt.scatter(temperature, apparant_temp)
plt.grid()
plt.xlabel('Temperature (C)')
plt.ylabel('Apparent Temperature (C)')
# Out:
# Text(0, 0.5, 'Apparent Temperature (C)')

# %%
plt.scatter(humidity, temperature)
plt.grid()
plt.xlabel('Humidity')
plt.ylabel('Temperature (C)')
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %% [markdown]
# ## Temperature and Apparent Temperature

# %%
cov = np.cov(df["Temperature (C)"],df["Apparent Temperature (C)"])
corr = np.corrcoef(df["Temperature (C)"],df["Apparent Temperature (C)"])
print("Covariance:  {}".format(cov[0,1]))
print("-----------------------------")
print("np.cov():\n {}".format(cov))
print("-----------------------------")
print("Correlation Cof: {}".format(corr[0,1]))
print("-----------------------------")
print("np.corrcoef():\n {}".format(corr))
# Out:
# Covariance:  101.418283188541
# -----------------------------
# np.cov():
#  [[ 91.23203712 101.41828319]
#  [101.41828319 114.42254413]]
# -----------------------------
# Correlation Cof: 0.9926285641920806
# -----------------------------
# np.corrcoef():
#  [[1.         0.99262856]
#  [0.99262856 1.        ]]

# %%
#type your code here:
# Out:
# Covariance:  [[101.41828319]]
# ---------------------------------------------------
# np.cov():
#  [[ 91.23203712 101.41828319]
#  [101.41828319 114.42254413]]
# ---------------------------------------------------
# Correlation Cof:  [[0.99262856]]
# ---------------------------------------------------
# np.corrcoef():
#  [[1.         0.99262856]
#  [0.99262856 1.        ]]

# %% [markdown]
# ## Temperature and Humidity

# %%
cov = np.cov(df["Temperature (C)"],df["Humidity"])
corr = np.corrcoef(df["Temperature (C)"],df["Humidity"])
print("Covariance:  {}".format(cov[0,1]))
print("-----------------------------")
print("np.cov():\n {}".format(cov))
print("-----------------------------")
print("Correlation Cof: {}".format(corr[0,1]))
print("-----------------------------")
print("np.corrcoef():\n {}".format(corr))
# Out:
# Covariance:  -1.180461789785137
# -----------------------------
# np.cov():
#  [[ 9.12320371e+01 -1.18046179e+00]
#  [-1.18046179e+00  3.82095917e-02]]
# -----------------------------
# Correlation Cof: -0.6322546750264326
# -----------------------------
# np.corrcoef():
#  [[ 1.         -0.63225468]
#  [-0.63225468  1.        ]]

# %%
#type your code here:
# Out:
# Covariance:  [[-1.18046179]]
# ---------------------------------------------------
# np.cov():
#  [[ 9.12320371e+01 -1.18046179e+00]
#  [-1.18046179e+00  3.82095917e-02]]
# ---------------------------------------------------
# Correlation Cof:  [[-0.63225468]]
# ---------------------------------------------------
# np.corrcoef():
#  [[ 1.         -0.63225468]
#  [-0.63225468  1.        ]]

# %%
import seaborn as sns
corr = df.corr()
sns.heatmap(corr,annot = True)
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')
